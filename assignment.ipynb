# %%
pip install --upgrade google-api-python-client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from googleapiclient.discovery import build

api_key='AIzaSyBG2Ex5xgwra0pJYibFonXWLZ7xjRNGVp4'

youtube=build('youtube','v3',developerKey=api_key)

request = youtube.search().list(
        part="snippet",
        maxResults=50,
        q="avatar movie")
response = request.execute()



data=dict(ID=response['items'][0]['id']['videoId'],
#           Snippet=response['items'][0]['snippet'],
          Channel_ID=response['items'][0]['snippet']['channelId'],
          Video_Description=response['items'][0]['snippet']['description'],
          Channel_Title=response['items'][0]['snippet']['channelTitle'],
          Video_Title=response['items'][0]['snippet']['title']
         )

print(data)
# Out:
# {'ID': 'w8PmrLG6v5I', 'Channel_ID': 'UCBOmfqgTZi7yDp4-3Lr_3lA', 'Video_Description': 'ShemarooMovies #Hindi #Movie #Bollywood #FullMovie #HD Click here to Subscribe the channel ...', 'Channel_Title': 'Shemaroo Movies', 'Video_Title': 'BOLLYWOOD BLOCKBUSTER HINDI MOVIE - राजेश खन्ना ,शबाना आजमी और सचिन की सुपरहिट हिंदी मूवी - AVTAAR'}

# %%
from googleapiclient.discovery import build

api_key='AIzaSyBG2Ex5xgwra0pJYibFonXWLZ7xjRNGVp4'

youtube=build('youtube','v3',developerKey=api_key)

request = youtube.search().list(
        part="snippet",
        maxResults=50,
        q="avatar movie",
        type="video")
response = request.execute()
ID=[]
video_id=[]
data=response['items']
# print(data)
# print(type(data))
for i in range(0,50):
    ID.append(data[i]['id'])
    
for j in range(0,50):
    video_id.append(ID[j]['videoId'])
# # ID=response['items']['id']['videoId']
print(len(video_id))
# Out:
# 50

# %%
request = youtube.videos().list(
        part="snippet,statistics",
        id="w8PmrLG6v5I,PLtgIILX7E8,6sjQGHq10Qo,51he5bnt07Q,d9MyW72ELq0,V_KfanT2fkU,6pHZmBin4Xc,Ehf6iESkLMk,q2QleUlhMQw,S4X0wi8oHPE,mdhEj_rG80Y,utN1jTz2jAs,n76KALvTN3Q,T4OPEBWYJng,ZM2k1UmcCXg,CyUXe8xAx9U,UO_aA5v3Qgg,LmFwxc86Fuc,yRR1K9dmhxw,noVddIRzn3o,w3wW4slmOhc,0sJeBiUCIt4,WDFr1O_GeAQ,a8Gx8wiNbs8,hM1zI8H7Tc8,3G6J-ITWekA,x0MwXUNhXKc,i12SONAAuqk,9N0n1BJgwKs,iLmYtr5Db4w,wlzni7Lcgtg,u3_Uhq6qxhU,XmxLG1HBNTk,-YL29aJyry8,IX7NZDXHfAM,Mw192fc8LsQ,E0lN5RIxYGQ,kA3j-NUxQBY,Zy3l3Opr5l0,U7cVZD0idBw,tw01WpmLbS8,mCBuaFbjW8k,jGWDkJ5zB7M,R6fnbPPokxE,vP67C8jQhLs,MgV9vymLIdQ,3b7sKh_QIbQ,xMZy72SVmwI,OHytHaN-UUA,nxjOFZqtLJc",
        maxResults=50,
        regionCode="US"
    )
response = request.execute()
data=response['items']
id=[]
title=[]
no_of_views=[]
# no_of_likes=[]
no_of_comments=[]
# print(data)
all_data=[]

for i in range(0,50):
    id.append(data[i]['id'])
    title.append(data[i]['snippet']['title'])
    no_of_views.append(data[i]['statistics']['viewCount'])
    no_of_comments.append(data[i]['statistics']['commentCount'])
#     no_of_likes.append(data[i]['statistics']['likeCount'])
# for j in range(0,49):
#     no_of_likes.append(data[j]['statistics']['likeCount'])
# print(len(no_of_comments))
# all_data.append(id)
# all_data.append(no_of_views)
# all_data.append(no_of_comments)
# print(all_data)
# Out:
# [['w8PmrLG6v5I', 'PLtgIILX7E8', '6sjQGHq10Qo', '51he5bnt07Q', 'd9MyW72ELq0', 'V_KfanT2fkU', '6pHZmBin4Xc', 'Ehf6iESkLMk', 'q2QleUlhMQw', 'S4X0wi8oHPE', 'mdhEj_rG80Y', 'utN1jTz2jAs', 'n76KALvTN3Q', 'T4OPEBWYJng', 'ZM2k1UmcCXg', 'CyUXe8xAx9U', 'UO_aA5v3Qgg', 'LmFwxc86Fuc', 'yRR1K9dmhxw', 'noVddIRzn3o', 'w3wW4slmOhc', '0sJeBiUCIt4', 'WDFr1O_GeAQ', 'a8Gx8wiNbs8', 'hM1zI8H7Tc8', '3G6J-ITWekA', 'x0MwXUNhXKc', 'i12SONAAuqk', '9N0n1BJgwKs', 'iLmYtr5Db4w', 'wlzni7Lcgtg', 'u3_Uhq6qxhU', 'XmxLG1HBNTk', '-YL29aJyry8', 'IX7NZDXHfAM', 'Mw192fc8LsQ', 'E0lN5RIxYGQ', 'kA3j-NUxQBY', 'Zy3l3Opr5l0', 'U7cVZD0idBw', 'tw01WpmLbS8', 'mCBuaFbjW8k', 'jGWDkJ5zB7M', 'R6fnbPPokxE', 'vP67C8jQhLs', 'MgV9vymLIdQ', '3b7sKh_QIbQ', 'xMZy72SVmwI', 'OHytHaN-UUA', 'nxjOFZqtLJc'], ['8572113', '29053309', '209765', '23448523', '57478503', '74699', '1685917', '1789317', '264', '87264', '1547974', '734711', '1234012', '3290853', '28292140', '180124', '125639', '324008', '5761573', '135728983', '90592', '31886787', '2249048',
# ...

# %%
import pandas as pd
dict = {'id': id,'title':title, 'no_of_views': no_of_views, 'no_of_comments': no_of_comments}
df = pd.DataFrame(dict)
     
# saving the dataframe
# df.to_csv('GFGF.csv')

# %%
df.dtypes
# Out:
# id                object
# title             object
# no_of_views       object
# no_of_comments    object
# dtype: object

# %%
df['no_of_comments'] = df['no_of_comments'].astype(str).astype(int)

# %%
df.dtypes
# Out:
# id                object
# title             object
# no_of_views       object
# no_of_comments     int32
# dtype: object

# %%
df1=df.sort_values(by=['no_of_comments'], ascending=False)
ten_highest_commented_vids=df1.head(10)
ten_highest_commented_vids
# Out:
#              id                                              title  \
# 4   d9MyW72ELq0        Avatar: The Way of Water | Official Trailer
# 23  a8Gx8wiNbs8  Avatar: The Way of Water | Official Teaser Tra...
# 45  MgV9vymLIdQ  The Last Airbender is the Worst Film Ever Made...
# 3   51he5bnt07Q  Avtaar [1983] [HD] Rajesh Kahnna | Shabana Azm...
# 26  x0MwXUNhXKc  AVATAR 2 - New Trailer, Movies 2022 / 4K Ultra HD
# 21  0sJeBiUCIt4    AVATAR Clip - Final Battle (2009) James Cameron
# 19  noVddIRzn3o  Sander VS Avatar Jake Sully #sandervs #satisfy...
# 14  ZM2k1UmcCXg                       AVATAR Clip - "Ikran" (2009)
# 44  vP67C8jQhLs  Avatar Movie Review/Plot In Hindi & Urdu / Sto...
# 40  tw01WpmLbS8            Avatar 2: the Way of Water movie REVIEW
#
#    no_of_views  no_of_comments
# 4     57478503           43354
# 23    27567420           29184
# 45     5831050           14253
# 3     23448523            4875
# 26    34844815            3677
# 21    31886787            3665
# ...

# %%
from pprint import pprint 
list=[]
for i in ten_highest_commented_vids['id']:
#     print(type(i))
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=i
    )
    response = request.execute()
    list.append(response)
pprint(list)
# Out:
# [{'etag': 'CByAKZLs4woLfa4JrgQzXUqIu9s',
#   'items': [{'etag': 'wukPzTeQf7gpBfhbqPBfcIb1iAc',
#              'id': 'Ugyi1R7NCCE4OcT2vpZ4AaABAg',
#              'kind': 'youtube#commentThread',
#              'snippet': {'canReply': True,
#                          'isPublic': True,
#                          'topLevelComment': {'etag': 'GR3BpvaAhsfBltgAKhTRg422jUk',
#                                              'id': 'Ugyi1R7NCCE4OcT2vpZ4AaABAg',
#                                              'kind': 'youtube#comment',
#                                              'snippet': {'authorChannelId': {'value': 'UCfcCE9XW4Ilz7cZPzZJ3XGQ'},
#                                                          'authorChannelUrl': 'http://www.youtube.com/channel/UCfcCE9XW4Ilz7cZPzZJ3XGQ',
#                                                          'authorDisplayName': 'Anna '
#                                                                               'Kakhniashvili',
# ...

# %%
import json

with open('data.json', 'w') as f:
    json.dump(list, f, indent=4)
